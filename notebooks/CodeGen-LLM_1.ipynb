# %%
# !git clone https://github.com/Nishviprp/CodeGen-LLM.git
# %cd CodeGen-LLM/project
# !pip install -q transformers peft accelerate datasets rouge-score sentencepiece tqdm matplotlib seaborn
# Out:
# Cloning into 'CodeGen-LLM'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 46 (delta 9), reused 22 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 11.63 MiB | 5.45 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# [Errno 2] No such file or directory: 'CodeGen-LLM/project'
# /content
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !python data/prepare_data.py
# Out:
# python3: can't open file '/content/data/prepare_data.py': [Errno 2] No such file or directory

# %%
# %cd /content/CodeGen-LLM
# Out:
# /content/CodeGen-LLM

# %%
# !python data/prepare_data.py
# Out:
# ...
# This may take a few minutes on first run (downloads ~500MB).
#
# README.md: 100% 1.30k/1.30k [00:00<00:00, 3.31MB/s]
# ...
# Resolving data files: 100% 54/54 [00:00<00:00, 42469.98it/s]
#   Collected 500/5000 examples...
#   Collected 1000/5000 examples...
#   Collected 1500/5000 examples...
#   Collected 2000/5000 examples...
#   Collected 2500/5000 examples...
#   Collected 3000/5000 examples...
#   Collected 3500/5000 examples...
#   Collected 4000/5000 examples...
#   Collected 4500/5000 examples...
#   Collected 5000/5000 examples...
#
# Done. Saved 5000 training examples to data/python_dataset.json
# (Skipped 0 files that were too short)
#
# ...
# README.md: 100% 6.52k/6.52k [00:00<00:00, 18.0MB/s]
# Traceback (most recent call last):
#   File "/content/CodeGen-LLM/data/prepare_data.py", line 137, in <module>
#     prepare_eval_data(
#   File "/content/CodeGen-LLM/data/prepare_data.py", line 112, in prepare_eval_data
#     dataset = load_dataset("openai_humaneval", split="test")
# ...

# %%
# !python models/finetune.py
# Out:
# Using device: cuda
# Loading base model: Salesforce/codegen-350M-mono
# config.json: 100% 999/999 [00:00<00:00, 6.28MB/s]
# tokenizer_config.json: 100% 240/240 [00:00<00:00, 1.53MB/s]
# ...
# vocab.json: 100% 798k/798k [00:00<00:00, 92.7MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 106MB/s]
# added_tokens.json: 100% 1.00k/1.00k [00:00<00:00, 2.99MB/s]
# special_tokens_map.json: 100% 90.0/90.0 [00:00<00:00, 654kB/s]
# tokenizer.json: 100% 2.11M/2.11M [00:00<00:00, 150MB/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# pytorch_model.bin: 100% 797M/797M [00:11<00:00, 69.7MB/s]
# Loading weights: 100% 165/165 [00:00<00:00, 35213.97it/s]
# [transformers] CodeGenForCausalLM LOAD REPORT from: Salesforce/codegen-350M-mono
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# transformer.h.{0...19}.attn.causal_mask | UNEXPECTED |  |
#
# Notes:
# ...

# %%
# %cd /content/CodeGen-LLM
# !git pull
# Out:
# /content/CodeGen-LLM
# Already up to date.

# %%
# !python data/prepare_data.py
# Out:
# ...
# This may take a few minutes on first run (downloads ~500MB).
#
# ...
# Resolving data files: 100% 54/54 [00:00<00:00, 315889.00it/s]
#   Collected 500/5000 examples...
#   Collected 1000/5000 examples...
#   Collected 1500/5000 examples...
#   Collected 2000/5000 examples...
#   Collected 2500/5000 examples...
#   Collected 3000/5000 examples...
#   Collected 3500/5000 examples...
#   Collected 4000/5000 examples...
#   Collected 4500/5000 examples...
#   Collected 5000/5000 examples...
#
# Done. Saved 5000 training examples to data/python_dataset.json
# (Skipped 0 files that were too short)
#
# ...
# README.md: 100% 6.52k/6.52k [00:00<00:00, 17.8MB/s]
# openai_humaneval/test-00000-of-00001.par(…): 100% 83.9k/83.9k [00:01<00:00, 80.9kB/s]
# Generating test split: 100% 164/164 [00:00<00:00, 6923.04 examples/s]
# Done. Saved 164 HumanEval tasks to data/human_eval.json
#
# All data ready. Next step: python models/finetune.py

# %%
# !pip uninstall -y torchao
# !pip install -q "peft==0.11.1"
# Out:
# Found existing installation: torchao 0.10.0
# Uninstalling torchao-0.10.0:
#   Successfully uninstalled torchao-0.10.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 20.4 MB/s eta 0:00:00

# %%
# !python models/finetune.py
# Out:
# Using device: cuda
# Loading base model: Salesforce/codegen-350M-mono
# ...
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 165/165 [00:00<00:00, 24013.19it/s]
# [transformers] CodeGenForCausalLM LOAD REPORT from: Salesforce/codegen-350M-mono
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# transformer.h.{0...19}.attn.causal_mask | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# trainable params: 983,040 || all params: 357,695,488 || trainable%: 0.2748
# Loading training data from data/python_dataset.json...
#   Loaded 5000 training examples
#
# Map: 100% 5000/5000 [00:30<00:00, 162.07 examples/s]
# Tokenized 5000 examples
#
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
#
# Starting fine-tuning...
#
# ...

# %%
# !python models/finetune.py
# Out:
# Using device: cuda
# Loading base model: Salesforce/codegen-350M-mono
# ...
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 165/165 [00:02<00:00, 69.38it/s]
# [transformers] CodeGenForCausalLM LOAD REPORT from: Salesforce/codegen-350M-mono
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# transformer.h.{0...19}.attn.causal_mask | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# trainable params: 983,040 || all params: 357,695,488 || trainable%: 0.2748
# Loading training data from data/python_dataset.json...
#   Loaded 5000 training examples
#
# Map: 100% 5000/5000 [01:10<00:00, 71.42 examples/s]
# Tokenized 5000 examples
#
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
#
# Starting fine-tuning...
#
# ...

# %%
import shutil
shutil.make_archive('finetuned-adapter', 'zip', 'models/finetuned-adapter')
from google.colab import files
files.download('finetuned-adapter.zip')
