# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Nishviprp/CodeGen-LLM.git
# %cd /content/CodeGen-LLM
# !pip install -q transformers peft accelerate datasets rouge-score sentencepiece tqdm matplotlib seaborn
# !pip uninstall -y torchao
# !pip install -q "peft==0.11.1"
# Out:
# Cloning into 'CodeGen-LLM'...
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 63 (delta 16), reused 35 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (63/63), 13.73 MiB | 17.60 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# /content/CodeGen-LLM
#   Preparing metadata (setup.py) ... done
# ...
# Found existing installation: torchao 0.10.0
# Uninstalling torchao-0.10.0:
#   Successfully uninstalled torchao-0.10.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 21.9 MB/s eta 0:00:00

# %%
# %cd /content/CodeGen-LLM
# !python data/prepare_data.py
# Out:
# /content/CodeGen-LLM
# ...
# This may take a few minutes on first run (downloads ~500MB).
#
# ...
# README.md: 100% 1.30k/1.30k [00:00<00:00, 3.93MB/s]
# Resolving data files: 100% 54/54 [00:00<00:00, 39700.69it/s]
#   Collected 500/5000 examples...
#   Collected 1000/5000 examples...
#   Collected 1500/5000 examples...
#   Collected 2000/5000 examples...
#   Collected 2500/5000 examples...
#   Collected 3000/5000 examples...
#   Collected 3500/5000 examples...
#   Collected 4000/5000 examples...
#   Collected 4500/5000 examples...
#   Collected 5000/5000 examples...
#
# Done. Saved 5000 training examples to data/python_dataset.json
# (Skipped 0 files that were too short)
#
# ...
# README.md: 100% 6.52k/6.52k [00:00<00:00, 19.6MB/s]
# openai_humaneval/test-00000-of-00001.par(…): 100% 83.9k/83.9k [00:01<00:00, 77.7kB/s]
# Generating test split: 100% 164/164 [00:00<00:00, 5982.53 examples/s]
# Done. Saved 164 HumanEval tasks to data/human_eval.json
#
# ...

# %%
# %cd /content/CodeGen-LLM
import shutil, os
os.makedirs('/content/drive/MyDrive/CodeGenLLM_results', exist_ok=True)
# !python evaluation/evaluator.py
# immediately copy results to Drive after it finishes
shutil.copytree('results', '/content/drive/MyDrive/CodeGenLLM_results', dirs_exist_ok=True)
print("Results copied to Google Drive safe even if this session ends.")
# Out:
# /content/CodeGen-LLM
# Evaluating on 164 HumanEval tasks, 5 samples/task/model
#
# [CodeGen] Loading base model 'Salesforce/codegen-350M-mono' on cuda...
# config.json: 100% 999/999 [00:00<00:00, 5.62MB/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# pytorch_model.bin: 100% 797M/797M [00:04<00:00, 164MB/s]
# Loading weights: 100% 165/165 [00:00<00:00, 19738.75it/s]
# [transformers] CodeGenForCausalLM LOAD REPORT from: Salesforce/codegen-350M-mono
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# transformer.h.{0...19}.attn.causal_mask | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ...

# %%
# %cd /content/CodeGen-LLM
# !python evaluation/visualize.py
import shutil
shutil.copytree('results/visualizations', '/content/drive/MyDrive/CodeGenLLM_results/visualizations', dirs_exist_ok=True)
print("Charts copied to Google Drive.")
# Out:
# /content/CodeGen-LLM
# Loading results...
# Generating charts...
#   Saved results/visualizations/pass_at_k.png
#   Saved results/visualizations/latency.png
#   Saved results/visualizations/complexity.png
#   Saved results/visualizations/rouge_scores.png
#   Saved results/visualizations/per_task_pass1.png
#
# All charts saved to results/visualizations/
# Charts copied to Google Drive.

# %%
from google.colab import files
import os
for f in os.listdir('/content/drive/MyDrive/CodeGenLLM_results'):
    full_path = f'/content/drive/MyDrive/CodeGenLLM_results/{f}'
    if os.path.isfile(full_path):
        files.download(full_path)
